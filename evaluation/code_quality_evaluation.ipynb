# %%
import pylint
import pylint.lint
from radon.complexity import cc_rank
from radon.visitors import ComplexityVisitor
from astroid import MANAGER

def calculate_score(code_doc):
    pylint_scores = []
    radon_scores = {"lineno": [], "complexity": []}
    for code in code_doc.split("----------\n"):
        MANAGER.astroid_cache.clear()
        # func = """""" + code
        func = code

        text_file = open("test.py", "w")
        text_file.write(func)
        text_file.close()
        score = pylint.lint.Run(['test.py'], exit=False).linter.stats.global_note
        pylint_scores.append(score)

        v = ComplexityVisitor.from_code(code)
        radon_scores['lineno'].append(v.functions[0][1])
        radon_scores["complexity"].append(v.functions[0][-1])

    return pylint_scores, radon_scores

# %% [markdown]
# ## Teak

# %%
TradeSweep = open("./teak/TradeSweep.py", "r").read()
baseline1 = open("./teak/baseline1.py", "r").read()
baseline2 = open("./teak/baseline2.py", "r").read()
baseline3 = open("./teak/baseline3.py", "r").read()

# %%
# TradeSweep

pylint_scores, radon_scores = calculate_score(TradeSweep)
print("=============== TradeSweep ===============")
print("\n\n----------- Pylint ----------")
print(pylint_scores)
print("Avg: ", round(sum(pylint_scores)/len(pylint_scores), 2))

print("\n----------- Radon ----------")
print("# of lines: ", radon_scores['lineno'])
print("Avg # of lines: ", round(sum(radon_scores['lineno'])/len(radon_scores['lineno']), 2))
print("\nComplexity: ", radon_scores['complexity'])
print("Complexity: ", round(sum(radon_scores['complexity'])/len(radon_scores['complexity']), 2))
print("\nComplexity rank: ", [cc_rank(score) for score in radon_scores['complexity']])
print("Complexity: ", cc_rank(int(sum(radon_scores['complexity'])/len(radon_scores['complexity']))))
# Out:
# ************* Module test
# test.py:6:0: C0301: Line too long (509/100) (line-too-long)
# test.py:8:0: C0301: Line too long (132/100) (line-too-long)
# test.py:10:0: C0301: Line too long (535/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:15: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 0.00/10 (previous run: 6.25/10, -6.25)
#
# ************* Module test
# test.py:10:0: C0301: Line too long (126/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:16: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:11:8: W0702: No exception type(s) specified (bare-except)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.45/10 (previous run: 0.00/10, +5.45)
#
# ************* Module test
# test.py:7:0: C0301: Line too long (149/100) (line-too-long)
# test.py:15:0: C0301: Line too long (127/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:19: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
# test.py:11:15: R0124: Redundant comparison - hs != hs (comparison-with-itself)
# test.py:14:12: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:18:15: C1803: "hs == []" can be simplified to "not hs", if it is strictly a sequence, as an empty list is falsey (use-implicit-booleaness-not-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.79/10 (previous run: 5.45/10, +0.33)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:20: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:7:24: W0613: Unused argument 'col' (unused-argument)
# test.py:2:0: W0611: Unused numpy imported as np (unused-import)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.86/10 (previous run: 5.79/10, -2.93)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:21: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.25/10 (previous run: 2.86/10, +3.39)
#
# ************* Module test
# test.py:72:0: C0301: Line too long (106/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:11:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:11:0: R0914: Too many local variables (30/15) (too-many-locals)
# test.py:11:25: W0621: Redefining name 'df' from outer scope (line 8) (redefined-outer-name)
# test.py:17:4: W0702: No exception type(s) specified (bare-except)
# test.py:25:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:37:20: W0702: No exception type(s) specified (bare-except)
# test.py:45:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:53:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:59:15: R0124: Redundant comparison - value != value (comparison-with-itself)
# test.py:62:27: R0124: Redundant comparison - value_tmp != value_tmp (comparison-with-itself)
# test.py:65:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:69:11: R0124: Redundant comparison - name_before != name_before (comparison-with-itself)
# test.py:69:37: C0321: More than one statement on a single line (multiple-statements)
# test.py:11:0: R0912: Too many branches (21/12) (too-many-branches)
# test.py:11:0: R0915: Too many statements (52/50) (too-many-statements)
# test.py:58:19: W0612: Unused variable 'cnt' (unused-variable)
# test.py:61:31: W0612: Unused variable 'cnt_tmp' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.21/10 (previous run: 6.25/10, +0.96)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:16: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.25/10 (previous run: 7.21/10, -0.96)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (132/100) (line-too-long)
# test.py:8:0: C0301: Line too long (367/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:29:0: C0301: Line too long (110/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:28: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 6.25/10, -0.60)
#
# ************* Module test
# test.py:9:0: C0301: Line too long (184/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:21: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.25/10 (previous run: 5.65/10, +0.60)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:11:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:11:0: R0914: Too many local variables (30/15) (too-many-locals)
# test.py:11:20: W0621: Redefining name 'df' from outer scope (line 8) (redefined-outer-name)
# test.py:17:4: W0702: No exception type(s) specified (bare-except)
# test.py:25:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:37:20: W0702: No exception type(s) specified (bare-except)
# test.py:45:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:53:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:59:15: R0124: Redundant comparison - value != value (comparison-with-itself)
# test.py:62:27: R0124: Redundant comparison - value_tmp != value_tmp (comparison-with-itself)
# test.py:65:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:69:11: R0124: Redundant comparison - name_before != name_before (comparison-with-itself)
# test.py:69:37: C0321: More than one statement on a single line (multiple-statements)
# test.py:11:0: R0912: Too many branches (21/12) (too-many-branches)
# test.py:11:0: R0915: Too many statements (52/50) (too-many-statements)
# test.py:58:19: W0612: Unused variable 'cnt' (unused-variable)
# test.py:61:31: W0612: Unused variable 'cnt_tmp' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.35/10 (previous run: 6.25/10, +1.10)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:17: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.25/10 (previous run: 7.35/10, -1.10)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (126/100) (line-too-long)
# test.py:8:0: C0301: Line too long (367/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:29:0: C0304: Final newline missing (missing-final-newline)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 6.25/10, -0.60)
#
# =============== TradeSweep ===============
#
#
# ----------- Pylint ----------
# [0, 5.454545454545455, 5.7894736842105265, 2.8571428571428568, 6.25, 7.205882352941177, 6.25, 5.6521739130434785, 6.25, 7.352941176470589, 6.25, 5.6521739130434785]
# Avg:  5.41
#
# ----------- Radon ----------
# # of lines:  [7, 7, 8, 7, 7, 11, 7, 6, 7, 11, 7, 6]
# Avg # of lines:  7.58
#
# Complexity:  [3, 3, 10, 1, 1, 20, 1, 12, 1, 20, 1, 12]
# Complexity:  7.08
#
# Complexity rank:  ['A', 'A', 'B', 'A', 'A', 'C', 'A', 'C', 'A', 'C', 'A', 'C']
# Complexity:  B

# %%
# Baseline 1

pylint_scores, radon_scores = calculate_score(baseline1)
print("=============== Baseline 1 ===============")
print("\n\n----------- Pylint ----------")
print(pylint_scores)
print("Avg: ", round(sum(pylint_scores)/len(pylint_scores), 2))

print("\n----------- Radon ----------")
print("# of lines: ", radon_scores['lineno'])
print("Avg # of lines: ", round(sum(radon_scores['lineno'])/len(radon_scores['lineno']), 2))
print("\nComplexity: ", radon_scores['complexity'])
print("Complexity: ", round(sum(radon_scores['complexity'])/len(radon_scores['complexity']), 2))
print("\nComplexity rank: ", [cc_rank(score) for score in radon_scores['complexity']])
print("Complexity: ", cc_rank(int(sum(radon_scores['complexity'])/len(radon_scores['complexity']))))
# Out:
# ************* Module test
# test.py:6:0: C0301: Line too long (512/100) (line-too-long)
# test.py:8:0: C0301: Line too long (468/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:13: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 1.67/10 (previous run: 5.65/10, -3.99)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:16: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:2:0: W0611: Unused numpy imported as np (unused-import)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.29/10 (previous run: 1.67/10, +2.62)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (149/100) (line-too-long)
# test.py:12:0: C0301: Line too long (118/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:28: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:10:11: R0124: Redundant comparison - x != x (comparison-with-itself)
# test.py:10:17: C0321: More than one statement on a single line (multiple-statements)
# test.py:2:0: W0611: Unused numpy imported as np (unused-import)
#
# ------------------------------------------------------------------
# Your code has been rated at 3.33/10 (previous run: 4.29/10, -0.95)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:12: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:7:16: E0602: Undefined variable 'np' (undefined-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 0.00/10 (previous run: 3.33/10, -3.33)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:16: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 0.00/10, +5.00)
#
# ************* Module test
# test.py:6:99: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 5.00/10, +1.36)
#
# ************* Module test
# test.py:8:0: C0301: Line too long (118/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:29: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.29/10 (previous run: 6.36/10, -2.08)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (130/100) (line-too-long)
# test.py:10:0: C0325: Unnecessary parens after 'if' keyword (superfluous-parens)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:18: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:9:8: W0612: Unused variable 'index' (unused-variable)
# test.py:2:0: W0611: Unused numpy imported as np (unused-import)
#
# ------------------------------------------------------------------
# Your code has been rated at 3.64/10 (previous run: 4.29/10, -0.65)
#
# ************* Module test
# test.py:7:24: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:20: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.56/10 (previous run: 3.64/10, +1.92)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (156/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:19: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 5.56/10, +0.81)
#
# ************* Module test
# test.py:9:0: C0301: Line too long (107/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:20: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.29/10 (previous run: 6.36/10, -2.08)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (124/100) (line-too-long)
# test.py:10:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:13:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:28: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 3.33/10 (previous run: 4.29/10, -0.95)
#
# =============== Baseline 1 ===============
#
#
# ----------- Pylint ----------
# [1.666666666666666, 4.2857142857142865, 3.333333333333334, 0, 5.0, 6.363636363636363, 4.2857142857142865, 3.6363636363636367, 5.555555555555555, 6.363636363636363, 4.2857142857142865, 3.333333333333334]
# Avg:  4.01
#
# ----------- Radon ----------
# # of lines:  [7, 7, 7, 6, 7, 7, 7, 7, 7, 7, 7, 6]
# Avg # of lines:  6.83
#
# Complexity:  [1, 1, 6, 1, 1, 1, 1, 3, 2, 1, 1, 1]
# Complexity:  1.67
#
# Complexity rank:  ['A', 'A', 'B', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A']
# Complexity:  A

# %%
# Baseline 2

pylint_scores, radon_scores = calculate_score(baseline2)
print("=============== Baseline 2 ===============")
print("\n\n----------- Pylint ----------")
print(pylint_scores)
print("Avg: ", round(sum(pylint_scores)/len(pylint_scores), 2))

print("\n----------- Radon ----------")
print("# of lines: ", radon_scores['lineno'])
print("Avg # of lines: ", round(sum(radon_scores['lineno'])/len(radon_scores['lineno']), 2))
print("\nComplexity: ", radon_scores['complexity'])
print("Complexity: ", round(sum(radon_scores['complexity'])/len(radon_scores['complexity']), 2))
print("\nComplexity rank: ", [cc_rank(score) for score in radon_scores['complexity']])
print("Complexity: ", cc_rank(int(sum(radon_scores['complexity'])/len(radon_scores['complexity']))))
# Out:
# ************* Module test
# test.py:6:0: C0301: Line too long (509/100) (line-too-long)
# test.py:9:0: C0301: Line too long (2540/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:17: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 0.00/10 (previous run: 3.33/10, -3.33)
#
# ************* Module test
# test.py:11:0: C0301: Line too long (123/100) (line-too-long)
# test.py:14:0: C0301: Line too long (101/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:16: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
# test.py:12:8: W0702: No exception type(s) specified (bare-except)
# test.py:12:16: C0321: More than one statement on a single line (multiple-statements)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.17/10 (previous run: 0.00/10, +4.17)
#
# ************* Module test
# test.py:7:0: C0301: Line too long (157/100) (line-too-long)
# test.py:23:0: C0301: Line too long (104/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:19: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
# test.py:10:8: C0103: Variable name "HS" doesn't conform to snake_case naming style (invalid-name)
# test.py:11:15: R0124: Redundant comparison - HS != HS (comparison-with-itself)
# test.py:12:12: C0103: Variable name "HS" doesn't conform to snake_case naming style (invalid-name)
# test.py:13:12: C0103: Variable name "HS" doesn't conform to snake_case naming style (invalid-name)
# test.py:14:12: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:17:12: C0103: Variable name "HS" doesn't conform to snake_case naming style (invalid-name)
# test.py:18:15: C1803: "HS == []" can be simplified to "not HS", if it is strictly a sequence, as an empty list is falsey (use-implicit-booleaness-not-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 3.68/10 (previous run: 4.17/10, -0.48)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:12: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:9:8: R1724: Unnecessary "else" after "continue", remove the "else" and de-indent the code inside it (no-else-continue)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.00/10 (previous run: 3.68/10, +2.32)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:20: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.25/10 (previous run: 6.00/10, +0.25)
#
# ************* Module test
# test.py:12:0: C0301: Line too long (226/100) (line-too-long)
# test.py:45:51: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:10:0: R0914: Too many local variables (30/15) (too-many-locals)
# test.py:10:24: W0621: Redefining name 'df' from outer scope (line 7) (redefined-outer-name)
# test.py:19:4: W0702: No exception type(s) specified (bare-except)
# test.py:27:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:39:20: W0702: No exception type(s) specified (bare-except)
# test.py:47:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:50:10: E0602: Undefined variable 'KMeans' (undefined-variable)
# test.py:55:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:61:15: R0124: Redundant comparison - value != value (comparison-with-itself)
# test.py:64:27: R0124: Redundant comparison - value_tmp != value_tmp (comparison-with-itself)
# test.py:67:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:71:11: R0124: Redundant comparison - name_before != name_before (comparison-with-itself)
# test.py:71:37: C0321: More than one statement on a single line (multiple-statements)
# test.py:10:0: R0912: Too many branches (21/12) (too-many-branches)
# test.py:10:0: R0915: Too many statements (52/50) (too-many-statements)
# test.py:60:19: W0612: Unused variable 'cnt' (unused-variable)
# test.py:63:31: W0612: Unused variable 'cnt_tmp' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.42/10 (previous run: 6.25/10, +0.17)
#
# ************* Module test
# test.py:9:0: C0301: Line too long (186/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:22: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.25/10 (previous run: 6.42/10, -0.17)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (157/100) (line-too-long)
# test.py:8:0: C0301: Line too long (367/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:29:0: C0301: Line too long (104/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 6.25/10, -0.60)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:21: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.25/10 (previous run: 5.65/10, +0.60)
#
# ************* Module test
# test.py:12:0: C0301: Line too long (226/100) (line-too-long)
# test.py:45:51: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:10:0: R0914: Too many local variables (30/15) (too-many-locals)
# test.py:10:24: W0621: Redefining name 'df' from outer scope (line 7) (redefined-outer-name)
# test.py:19:4: W0702: No exception type(s) specified (bare-except)
# test.py:27:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:39:20: W0702: No exception type(s) specified (bare-except)
# test.py:47:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:50:10: E0602: Undefined variable 'KMeans' (undefined-variable)
# test.py:55:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:61:15: R0124: Redundant comparison - value != value (comparison-with-itself)
# test.py:64:27: R0124: Redundant comparison - value_tmp != value_tmp (comparison-with-itself)
# test.py:67:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:71:11: R0124: Redundant comparison - name_before != name_before (comparison-with-itself)
# test.py:71:37: C0321: More than one statement on a single line (multiple-statements)
# test.py:10:0: R0912: Too many branches (21/12) (too-many-branches)
# test.py:10:0: R0915: Too many statements (52/50) (too-many-statements)
# test.py:60:19: W0612: Unused variable 'cnt' (unused-variable)
# test.py:63:31: W0612: Unused variable 'cnt_tmp' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.42/10 (previous run: 6.25/10, +0.17)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:26: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.25/10 (previous run: 6.42/10, -0.17)
#
# ************* Module test
# test.py:5:152: E2515: Invalid unescaped character zero-width-space, use "\u200B" instead. (invalid-character-zero-width-space)
# test.py:5:0: C0301: Line too long (152/100) (line-too-long)
# test.py:8:0: C0301: Line too long (367/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 3.91/10 (previous run: 6.25/10, -2.34)
#
# =============== Baseline 2 ===============
#
#
# ----------- Pylint ----------
# [0, 4.166666666666666, 3.6842105263157894, 6.0, 6.25, 6.417910447761194, 6.25, 5.6521739130434785, 6.25, 6.417910447761194, 6.25, 3.913043478260869]
# Avg:  5.1
#
# ----------- Radon ----------
# # of lines:  [7, 8, 8, 6, 7, 10, 7, 6, 7, 10, 7, 6]
# Avg # of lines:  7.42
#
# Complexity:  [1, 3, 9, 3, 1, 20, 1, 12, 1, 20, 1, 12]
# Complexity:  7.0
#
# Complexity rank:  ['A', 'A', 'B', 'A', 'A', 'C', 'A', 'C', 'A', 'C', 'A', 'C']
# Complexity:  B

# %%
# Baseline 3

pylint_scores, radon_scores = calculate_score(baseline3)
print("=============== Baseline 3 ===============")
print("\n\n----------- Pylint ----------")
print(pylint_scores)
print("Avg: ", round(sum(pylint_scores)/len(pylint_scores), 2))

print("\n----------- Radon ----------")
print("# of lines: ", radon_scores['lineno'])
print("Avg # of lines: ", round(sum(radon_scores['lineno'])/len(radon_scores['lineno']), 2))
print("\nComplexity: ", radon_scores['complexity'])
print("Complexity: ", round(sum(radon_scores['complexity'])/len(radon_scores['complexity']), 2))
print("\nComplexity rank: ", [cc_rank(score) for score in radon_scores['complexity']])
print("Complexity: ", cc_rank(int(sum(radon_scores['complexity'])/len(radon_scores['complexity']))))
# Out:
# ************* Module test
# test.py:6:0: C0301: Line too long (509/100) (line-too-long)
# test.py:9:0: C0301: Line too long (2540/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:17: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 0.00/10 (previous run: 3.91/10, -3.91)
#
# ************* Module test
# test.py:11:0: C0301: Line too long (133/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:16: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
# test.py:12:8: W0702: No exception type(s) specified (bare-except)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.83/10 (previous run: 0.00/10, +5.83)
#
# ************* Module test
# test.py:7:0: C0301: Line too long (149/100) (line-too-long)
# test.py:15:0: C0301: Line too long (101/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:19: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
# test.py:10:8: C0103: Variable name "HS" doesn't conform to snake_case naming style (invalid-name)
# test.py:11:15: R0124: Redundant comparison - HS != HS (comparison-with-itself)
# test.py:12:12: C0103: Variable name "HS" doesn't conform to snake_case naming style (invalid-name)
# test.py:13:12: C0103: Variable name "HS" doesn't conform to snake_case naming style (invalid-name)
# test.py:14:12: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:17:12: C0103: Variable name "HS" doesn't conform to snake_case naming style (invalid-name)
# test.py:18:15: C1803: "HS == []" can be simplified to "not HS", if it is strictly a sequence, as an empty list is falsey (use-implicit-booleaness-not-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 3.68/10 (previous run: 5.83/10, -2.15)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:19: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 3.68/10, +1.32)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:28: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.25/10 (previous run: 5.00/10, +1.25)
#
# ************* Module test
# test.py:42:51: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:10:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:10:0: R0914: Too many local variables (30/15) (too-many-locals)
# test.py:10:25: W0621: Redefining name 'df' from outer scope (line 7) (redefined-outer-name)
# test.py:16:4: W0702: No exception type(s) specified (bare-except)
# test.py:24:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:36:20: W0702: No exception type(s) specified (bare-except)
# test.py:44:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:47:10: E0602: Undefined variable 'KMeans' (undefined-variable)
# test.py:52:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:58:15: R0124: Redundant comparison - value != value (comparison-with-itself)
# test.py:61:27: R0124: Redundant comparison - value_tmp != value_tmp (comparison-with-itself)
# test.py:64:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:68:11: R0124: Redundant comparison - name_before != name_before (comparison-with-itself)
# test.py:68:37: C0321: More than one statement on a single line (multiple-statements)
# test.py:10:0: R0912: Too many branches (21/12) (too-many-branches)
# test.py:10:0: R0915: Too many statements (52/50) (too-many-statements)
# test.py:57:19: W0612: Unused variable 'cnt' (unused-variable)
# test.py:60:31: W0612: Unused variable 'cnt_tmp' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.42/10 (previous run: 6.25/10, +0.17)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:28: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.25/10 (previous run: 6.42/10, -0.17)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (132/100) (line-too-long)
# test.py:13:0: C0301: Line too long (126/100) (line-too-long)
# test.py:16:0: C0301: Line too long (106/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:18: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:10:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:15:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:21:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:21:21: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 6.25/10, -0.60)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:24: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.25/10 (previous run: 5.65/10, +0.60)
#
# ************* Module test
# test.py:42:51: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:10:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:10:0: R0914: Too many local variables (30/15) (too-many-locals)
# test.py:10:25: W0621: Redefining name 'df' from outer scope (line 7) (redefined-outer-name)
# test.py:16:4: W0702: No exception type(s) specified (bare-except)
# test.py:24:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:36:20: W0702: No exception type(s) specified (bare-except)
# test.py:44:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:47:10: E0602: Undefined variable 'KMeans' (undefined-variable)
# test.py:52:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:58:15: R0124: Redundant comparison - value != value (comparison-with-itself)
# test.py:61:27: R0124: Redundant comparison - value_tmp != value_tmp (comparison-with-itself)
# test.py:64:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:68:11: R0124: Redundant comparison - name_before != name_before (comparison-with-itself)
# test.py:68:37: C0321: More than one statement on a single line (multiple-statements)
# test.py:10:0: R0912: Too many branches (21/12) (too-many-branches)
# test.py:10:0: R0915: Too many statements (52/50) (too-many-statements)
# test.py:57:19: W0612: Unused variable 'cnt' (unused-variable)
# test.py:60:31: W0612: Unused variable 'cnt_tmp' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.42/10 (previous run: 6.25/10, +0.17)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:24: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.25/10 (previous run: 6.42/10, -0.17)
#
# ************* Module test
# test.py:5:127: E2515: Invalid unescaped character zero-width-space, use "\u200B" instead. (invalid-character-zero-width-space)
# test.py:5:0: C0301: Line too long (127/100) (line-too-long)
# test.py:13:0: C0301: Line too long (126/100) (line-too-long)
# test.py:16:0: C0301: Line too long (106/100) (line-too-long)
# test.py:26:0: C0301: Line too long (112/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:18: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:10:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:15:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:21:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:21:19: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 3.04/10 (previous run: 6.25/10, -3.21)
#
# =============== Baseline 3 ===============
#
#
# ----------- Pylint ----------
# [0, 5.833333333333333, 3.6842105263157894, 5.0, 6.25, 6.417910447761194, 6.25, 5.6521739130434785, 6.25, 6.417910447761194, 6.25, 3.0434782608695654]
# Avg:  5.09
#
# ----------- Radon ----------
# # of lines:  [7, 8, 8, 6, 7, 10, 7, 6, 7, 10, 7, 6]
# Avg # of lines:  7.42
#
# Complexity:  [1, 3, 9, 1, 1, 20, 1, 12, 1, 20, 1, 12]
# Complexity:  6.83
#
# Complexity rank:  ['A', 'A', 'B', 'A', 'A', 'C', 'A', 'C', 'A', 'C', 'A', 'C']
# Complexity:  B

# %% [markdown]
# ## Grain

# %%
TradeSweep = open("./grain/TradeSweep.py", "r").read()
baseline1 = open("./grain/baseline1.py", "r").read()
baseline2 = open("./grain/baseline2.py", "r").read()
baseline3 = open("./grain/baseline3.py", "r").read()

# %%
# TradeSweep

pylint_scores, radon_scores = calculate_score(TradeSweep)
print("=============== TradeSweep ===============")
print("\n\n----------- Pylint ----------")
print(pylint_scores)
print("Avg: ", round(sum(pylint_scores)/len(pylint_scores), 2))

print("\n----------- Radon ----------")
print("# of lines: ", radon_scores['lineno'])
print("Avg # of lines: ", round(sum(radon_scores['lineno'])/len(radon_scores['lineno']), 2))
print("\nComplexity: ", radon_scores['complexity'])
print("Complexity: ", round(sum(radon_scores['complexity'])/len(radon_scores['complexity']), 2))
print("\nComplexity rank: ", [cc_rank(score) for score in radon_scores['complexity']])
print("Complexity: ", cc_rank(int(sum(radon_scores['complexity'])/len(radon_scores['complexity']))))
# Out:
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:16: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:11:8: W0702: No exception type(s) specified (bare-except)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.00/10 (previous run: 5.65/10, +0.35)
#
# ************* Module test
# test.py:9:0: C0301: Line too long (226/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:18: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.69/10 (previous run: 6.00/10, +1.69)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (186/100) (line-too-long)
# test.py:9:0: C0301: Line too long (210/100) (line-too-long)
# test.py:27:0: C0301: Line too long (175/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:16:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:16:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:23:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 7.69/10, -1.33)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (131/100) (line-too-long)
# test.py:8:0: C0301: Line too long (367/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:29:0: C0301: Line too long (102/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 6.36/10, -0.71)
#
# ************* Module test
# test.py:10:0: C0301: Line too long (181/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:18: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 8.00/10 (previous run: 5.65/10, +2.35)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (186/100) (line-too-long)
# test.py:9:0: C0301: Line too long (210/100) (line-too-long)
# test.py:27:0: C0301: Line too long (232/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:16:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:16:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:23:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 8.00/10, -1.64)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (130/100) (line-too-long)
# test.py:8:0: C0301: Line too long (367/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:29:0: C0301: Line too long (102/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 6.36/10, -0.71)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (145/100) (line-too-long)
# test.py:8:0: C0301: Line too long (367/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.09/10 (previous run: 5.65/10, +0.43)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (131/100) (line-too-long)
# test.py:8:0: C0301: Line too long (367/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:29:0: C0301: Line too long (102/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 6.09/10, -0.43)
#
# ************* Module test
# test.py:10:0: C0301: Line too long (113/100) (line-too-long)
# test.py:12:0: C0301: Line too long (122/100) (line-too-long)
# test.py:13:0: C0301: Line too long (116/100) (line-too-long)
# test.py:19:0: C0301: Line too long (131/100) (line-too-long)
# test.py:23:0: C0301: Line too long (111/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:18: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 5.65/10, -0.65)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (192/100) (line-too-long)
# test.py:9:0: C0301: Line too long (210/100) (line-too-long)
# test.py:27:0: C0301: Line too long (137/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:16:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:16:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:23:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 5.00/10, +1.36)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (150/100) (line-too-long)
# test.py:8:0: C0301: Line too long (367/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.09/10 (previous run: 6.36/10, -0.28)
#
# ************* Module test
# test.py:9:0: C0301: Line too long (174/100) (line-too-long)
# test.py:11:180: C0303: Trailing whitespace (trailing-whitespace)
# test.py:11:0: C0301: Line too long (180/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:26: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.86/10 (previous run: 6.09/10, -3.23)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (192/100) (line-too-long)
# test.py:9:0: C0301: Line too long (210/100) (line-too-long)
# test.py:27:0: C0301: Line too long (137/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:16:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:16:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:23:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 2.86/10, +3.51)
#
# ************* Module test
# test.py:5:150: C0303: Trailing whitespace (trailing-whitespace)
# test.py:5:0: C0301: Line too long (150/100) (line-too-long)
# test.py:8:0: C0301: Line too long (358/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:29:0: C0301: Line too long (124/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:36: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.22/10 (previous run: 6.36/10, -1.15)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (121/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:31: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:16:23: W0718: Catching too general exception Exception (broad-exception-caught)
# test.py:16:16: W0612: Unused variable 'e' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.00/10 (previous run: 5.22/10, +0.78)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:24: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.71/10 (previous run: 6.00/10, -0.29)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (194/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.67/10 (previous run: 5.71/10, +0.95)
#
# =============== TradeSweep ===============
#
#
# ----------- Pylint ----------
# [6.0, 7.692307692307692, 6.363636363636363, 5.6521739130434785, 8.0, 6.363636363636363, 5.6521739130434785, 6.086956521739131, 5.6521739130434785, 5.0, 6.363636363636363, 6.086956521739131, 2.8571428571428568, 6.363636363636363, 5.217391304347826, 6.0, 5.714285714285714, 6.666666666666667]
# Avg:  5.99
#
# ----------- Radon ----------
# # of lines:  [7, 7, 7, 6, 8, 7, 6, 6, 6, 8, 7, 6, 7, 7, 6, 7, 7, 7]
# Avg # of lines:  6.78
#
# Complexity:  [3, 3, 6, 12, 3, 6, 12, 12, 12, 3, 6, 12, 2, 6, 12, 5, 1, 3]
# Complexity:  6.61
#
# Complexity rank:  ['A', 'A', 'B', 'C', 'A', 'B', 'C', 'C', 'C', 'A', 'B', 'C', 'A', 'B', 'C', 'A', 'A', 'A']
# Complexity:  B

# %%
# Baseline 1

pylint_scores, radon_scores = calculate_score(baseline1)
print("=============== Baseline 1 ===============")
print("\n\n----------- Pylint ----------")
print(pylint_scores)
print("Avg: ", round(sum(pylint_scores)/len(pylint_scores), 2))

print("\n----------- Radon ----------")
print("# of lines: ", radon_scores['lineno'])
print("Avg # of lines: ", round(sum(radon_scores['lineno'])/len(radon_scores['lineno']), 2))
print("\nComplexity: ", radon_scores['complexity'])
print("Complexity: ", round(sum(radon_scores['complexity'])/len(radon_scores['complexity']), 2))
print("\nComplexity rank: ", [cc_rank(score) for score in radon_scores['complexity']])
print("Complexity: ", cc_rank(int(sum(radon_scores['complexity'])/len(radon_scores['complexity']))))
# Out:
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:16: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.71/10 (previous run: 6.67/10, -0.95)
#
# ************* Module test
# test.py:6:27: C0303: Trailing whitespace (trailing-whitespace)
# test.py:7:80: C0303: Trailing whitespace (trailing-whitespace)
# test.py:9:13: C0303: Trailing whitespace (trailing-whitespace)
# test.py:7:59: W1401: Anomalous backslash in string: '\W'. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:23: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 0.00/10 (previous run: 5.71/10, -5.71)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (201/100) (line-too-long)
# test.py:10:0: C0301: Line too long (119/100) (line-too-long)
# test.py:15:0: C0301: Line too long (107/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:20: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:6:24: W0613: Unused argument 'col' (unused-argument)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.33/10 (previous run: 0.00/10, +5.33)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (129/100) (line-too-long)
# test.py:9:0: C0301: Line too long (113/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:31: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.44/10 (previous run: 5.33/10, -0.89)
#
# ************* Module test
# test.py:9:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:12:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:17:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:21:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:15: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.17/10 (previous run: 4.44/10, -0.28)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (101/100) (line-too-long)
# test.py:7:0: C0301: Line too long (134/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:36: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.83/10 (previous run: 4.17/10, +1.67)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (129/100) (line-too-long)
# test.py:10:0: C0301: Line too long (113/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:23: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.44/10 (previous run: 5.83/10, -1.39)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (142/100) (line-too-long)
# test.py:10:0: C0301: Line too long (115/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:23: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.44/10 (previous run: 4.44/10, +0.00)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (129/100) (line-too-long)
# test.py:9:0: C0301: Line too long (154/100) (line-too-long)
# test.py:10:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:12:0: C0301: Line too long (136/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:20: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:7:24: W0613: Unused argument 'col' (unused-argument)
#
# ------------------------------------------------------------------
# Your code has been rated at 0.00/10 (previous run: 4.44/10, -4.44)
#
# ************* Module test
# test.py:6:23: C0303: Trailing whitespace (trailing-whitespace)
# test.py:8:72: C0303: Trailing whitespace (trailing-whitespace)
# test.py:9:72: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:19: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.50/10 (previous run: 0.00/10, +2.50)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (107/100) (line-too-long)
# test.py:7:0: C0301: Line too long (139/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:26: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.67/10 (previous run: 2.50/10, +4.17)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (146/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:37: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 6.67/10, -1.67)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:27: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 5.00/10, +0.00)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (107/100) (line-too-long)
# test.py:8:0: C0301: Line too long (141/100) (line-too-long)
# test.py:9:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:12:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:20:0: C0301: Line too long (107/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:26: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 5.00/10, +0.00)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (150/100) (line-too-long)
# test.py:10:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:18:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:21:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:21: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:12:8: W0612: Unused variable 'name' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 3.85/10 (previous run: 5.00/10, -1.15)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (121/100) (line-too-long)
# test.py:8:0: C0301: Line too long (141/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:34: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.86/10 (previous run: 3.85/10, -0.99)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:20: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:7:24: W0613: Unused argument 'col' (unused-argument)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.29/10 (previous run: 2.86/10, +1.43)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (291/100) (line-too-long)
# test.py:8:0: C0301: Line too long (129/100) (line-too-long)
# test.py:9:0: C0301: Line too long (104/100) (line-too-long)
# test.py:10:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:11:0: C0301: Line too long (111/100) (line-too-long)
# test.py:12:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:28: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:9:29: R1721: Unnecessary use of a comprehension, use dict(trading_countries[['ISO2CTY', 'Country']].values) instead. (unnecessary-comprehension)
#
# ------------------------------------------------------------------
# Your code has been rated at 0.00/10 (previous run: 4.29/10, -4.29)
#
# =============== Baseline 1 ===============
#
#
# ----------- Pylint ----------
# [5.714285714285714, 0, 5.333333333333333, 4.444444444444445, 4.166666666666666, 5.833333333333333, 4.444444444444445, 4.444444444444445, 0, 2.5, 6.666666666666667, 5.0, 5.0, 5.0, 3.846153846153846, 2.8571428571428568, 4.2857142857142865, 0]
# Avg:  3.86
#
# ----------- Radon ----------
# # of lines:  [7, 6, 6, 6, 6, 6, 6, 6, 7, 6, 6, 6, 6, 6, 7, 7, 7, 7]
# Avg # of lines:  6.33
#
# Complexity:  [1, 1, 5, 1, 2, 4, 1, 1, 2, 1, 5, 1, 1, 5, 3, 2, 1, 3]
# Complexity:  2.22
#
# Complexity rank:  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A']
# Complexity:  A

# %%
# Baseline 2

pylint_scores, radon_scores = calculate_score(baseline2)
print("=============== Baseline 2 ===============")
print("\n\n----------- Pylint ----------")
print(pylint_scores)
print("Avg: ", round(sum(pylint_scores)/len(pylint_scores), 2))

print("\n----------- Radon ----------")
print("# of lines: ", radon_scores['lineno'])
print("Avg # of lines: ", round(sum(radon_scores['lineno'])/len(radon_scores['lineno']), 2))
print("\nComplexity: ", radon_scores['complexity'])
print("Complexity: ", round(sum(radon_scores['complexity'])/len(radon_scores['complexity']), 2))
print("\nComplexity rank: ", [cc_rank(score) for score in radon_scores['complexity']])
print("Complexity: ", cc_rank(int(sum(radon_scores['complexity'])/len(radon_scores['complexity']))))
# Out:
# ************* Module test
# test.py:12:0: C0301: Line too long (105/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:9:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:9:16: W0621: Redefining name 'df' from outer scope (line 6) (redefined-outer-name)
# test.py:13:8: W0702: No exception type(s) specified (bare-except)
# test.py:3:0: W0611: Unused import dateutil (unused-import)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 5.00/10, +0.00)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:18: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 8.00/10 (previous run: 5.00/10, +3.00)
#
# ************* Module test
# test.py:7:0: C0301: Line too long (179/100) (line-too-long)
# test.py:9:134: C0303: Trailing whitespace (trailing-whitespace)
# test.py:9:0: C0301: Line too long (134/100) (line-too-long)
# test.py:10:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:14:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:20:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:23: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
# test.py:16:37: R0124: Redundant comparison - sender_name != sender_name (comparison-with-itself)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.44/10 (previous run: 8.00/10, -3.56)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (121/100) (line-too-long)
# test.py:8:0: C0301: Line too long (367/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:29:0: C0301: Line too long (153/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 4.44/10, +1.21)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:18: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 8.00/10 (previous run: 5.65/10, +2.35)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (179/100) (line-too-long)
# test.py:9:0: C0301: Line too long (210/100) (line-too-long)
# test.py:27:0: C0301: Line too long (175/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:16:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:16:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:23:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 8.00/10, -1.64)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (129/100) (line-too-long)
# test.py:8:0: C0301: Line too long (367/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:29:0: C0301: Line too long (102/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 6.36/10, -0.71)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (130/100) (line-too-long)
# test.py:13:0: C0301: Line too long (118/100) (line-too-long)
# test.py:26:0: C0301: Line too long (104/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:10:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:15:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:21:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:21:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 5.65/10, +0.00)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (122/100) (line-too-long)
# test.py:8:0: C0301: Line too long (367/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:29:0: C0301: Line too long (102/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 5.65/10, +0.00)
#
# ************* Module test
# test.py:10:0: C0301: Line too long (181/100) (line-too-long)
# test.py:21:0: C0301: Line too long (111/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:18: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.33/10 (previous run: 5.65/10, +1.68)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (185/100) (line-too-long)
# test.py:24:0: C0301: Line too long (181/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:13:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:20:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 7.33/10, -0.97)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (136/100) (line-too-long)
# test.py:8:0: C0301: Line too long (367/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:29:0: C0301: Line too long (110/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 6.36/10, -0.71)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:20: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 8.00/10 (previous run: 5.65/10, +2.35)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (185/100) (line-too-long)
# test.py:24:196: C0303: Trailing whitespace (trailing-whitespace)
# test.py:24:0: C0301: Line too long (196/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:24: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:13:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:20:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.91/10 (previous run: 8.00/10, -2.09)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (136/100) (line-too-long)
# test.py:8:0: C0301: Line too long (367/100) (line-too-long)
# test.py:16:0: C0301: Line too long (158/100) (line-too-long)
# test.py:19:0: C0301: Line too long (129/100) (line-too-long)
# test.py:29:0: C0301: Line too long (110/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.22/10 (previous run: 5.91/10, -0.69)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (118/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:31: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:12:8: W0702: No exception type(s) specified (bare-except)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.15/10 (previous run: 5.22/10, +0.94)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:21: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.71/10 (previous run: 6.15/10, -0.44)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (191/100) (line-too-long)
# test.py:8:0: C0301: Line too long (117/100) (line-too-long)
# test.py:17:0: C0301: Line too long (155/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:0: R0913: Too many arguments (6/5) (too-many-arguments)
# test.py:6:39: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:9:4: W0702: No exception type(s) specified (bare-except)
# test.py:12:18: E0602: Undefined variable 'np' (undefined-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 0.71/10 (previous run: 5.71/10, -5.00)
#
# =============== Baseline 2 ===============
#
#
# ----------- Pylint ----------
# [5.0, 8.0, 4.444444444444445, 5.6521739130434785, 8.0, 6.363636363636363, 5.6521739130434785, 5.6521739130434785, 5.6521739130434785, 7.333333333333334, 6.363636363636363, 5.6521739130434785, 8.0, 5.909090909090909, 5.217391304347826, 6.153846153846153, 5.714285714285714, 0.7142857142857135]
# Avg:  5.86
#
# ----------- Radon ----------
# # of lines:  [9, 8, 8, 6, 8, 7, 6, 6, 6, 8, 7, 6, 8, 7, 6, 7, 7, 6]
# Avg # of lines:  7.0
#
# Complexity:  [3, 3, 7, 12, 3, 6, 12, 12, 12, 3, 6, 12, 3, 6, 12, 4, 1, 4]
# Complexity:  6.72
#
# Complexity rank:  ['A', 'A', 'B', 'C', 'A', 'B', 'C', 'C', 'C', 'A', 'B', 'C', 'A', 'B', 'C', 'A', 'A', 'A']
# Complexity:  B

# %%
# Baseline 3

pylint_scores, radon_scores = calculate_score(baseline3)
print("=============== Baseline 3 ===============")
print("\n\n----------- Pylint ----------")
print(pylint_scores)
print("Avg: ", round(sum(pylint_scores)/len(pylint_scores), 2))

print("\n----------- Radon ----------")
print("# of lines: ", radon_scores['lineno'])
print("Avg # of lines: ", round(sum(radon_scores['lineno'])/len(radon_scores['lineno']), 2))
print("\nComplexity: ", radon_scores['complexity'])
print("Complexity: ", round(sum(radon_scores['complexity'])/len(radon_scores['complexity']), 2))
print("\nComplexity rank: ", [cc_rank(score) for score in radon_scores['complexity']])
print("Complexity: ", cc_rank(int(sum(radon_scores['complexity'])/len(radon_scores['complexity']))))
# Out:
# ************* Module test
# test.py:13:0: C0301: Line too long (133/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:10:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:10:22: W0621: Redefining name 'df' from outer scope (line 7) (redefined-outer-name)
# test.py:14:8: W0702: No exception type(s) specified (bare-except)
# test.py:5:0: W0611: Unused numpy imported as np (unused-import)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.38/10 (previous run: 5.38/10, +0.00)
#
# ************* Module test
# test.py:13:0: C0301: Line too long (158/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:31: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
# test.py:11:35: C0123: Use isinstance() rather than type() for a typecheck. (unidiomatic-typecheck)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.43/10 (previous run: 5.38/10, +1.04)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (186/100) (line-too-long)
# test.py:24:0: C0301: Line too long (175/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:13:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:20:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 6.43/10, -0.06)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (131/100) (line-too-long)
# test.py:13:0: C0301: Line too long (118/100) (line-too-long)
# test.py:26:0: C0301: Line too long (110/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:30: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:10:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:15:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:21:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:21:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 6.36/10, -0.71)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:18: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 8.00/10 (previous run: 5.65/10, +2.35)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (186/100) (line-too-long)
# test.py:24:0: C0301: Line too long (131/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:13:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:20:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 8.00/10, -1.64)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (131/100) (line-too-long)
# test.py:13:0: C0301: Line too long (118/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:10:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:15:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:21:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:21:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.09/10 (previous run: 6.36/10, -0.28)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (147/100) (line-too-long)
# test.py:13:0: C0301: Line too long (118/100) (line-too-long)
# test.py:26:0: C0301: Line too long (104/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:10:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:15:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:21:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:21:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 6.09/10, -0.43)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (138/100) (line-too-long)
# test.py:13:0: C0301: Line too long (118/100) (line-too-long)
# test.py:26:0: C0301: Line too long (102/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:10:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:15:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:21:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:21:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 5.65/10, +0.00)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:18: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 8.00/10 (previous run: 5.65/10, +2.35)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (192/100) (line-too-long)
# test.py:24:0: C0301: Line too long (137/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:13:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:20:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 8.00/10, -1.64)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (152/100) (line-too-long)
# test.py:13:0: C0301: Line too long (118/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:10:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:15:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:21:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:21:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.09/10 (previous run: 6.36/10, -0.28)
#
# ************* Module test
# test.py:8:0: C0301: Line too long (117/100) (line-too-long)
# test.py:8:65: W1401: Anomalous backslash in string: '\s'. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:24: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 3.75/10 (previous run: 6.09/10, -2.34)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (192/100) (line-too-long)
# test.py:24:0: C0301: Line too long (137/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:13:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:20:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 3.75/10, +2.61)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (152/100) (line-too-long)
# test.py:13:0: C0301: Line too long (118/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:10:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:15:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:21:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:21:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.09/10 (previous run: 6.36/10, -0.28)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (121/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:20: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:16:23: W0718: Catching too general exception Exception (broad-exception-caught)
# test.py:16:16: W0612: Unused variable 'e' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.00/10 (previous run: 6.09/10, -0.09)
#
# ************* Module test
# test.py:8:0: C0301: Line too long (110/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:32: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.29/10 (previous run: 6.00/10, -1.71)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (194/100) (line-too-long)
# test.py:8:0: C0301: Line too long (109/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:27: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.83/10 (previous run: 4.29/10, +1.55)
#
# =============== Baseline 3 ===============
#
#
# ----------- Pylint ----------
# [5.384615384615384, 6.428571428571429, 6.363636363636363, 5.6521739130434785, 8.0, 6.363636363636363, 6.086956521739131, 5.6521739130434785, 5.6521739130434785, 8.0, 6.363636363636363, 6.086956521739131, 3.75, 6.363636363636363, 6.086956521739131, 6.0, 4.2857142857142865, 5.833333333333333]
# Avg:  6.02
#
# ----------- Radon ----------
# # of lines:  [10, 8, 7, 6, 8, 7, 6, 6, 6, 8, 7, 6, 6, 7, 6, 7, 7, 7]
# Avg # of lines:  6.94
#
# Complexity:  [3, 4, 6, 12, 3, 6, 12, 12, 12, 3, 6, 12, 1, 6, 12, 5, 1, 3]
# Complexity:  6.61
#
# Complexity rank:  ['A', 'A', 'B', 'C', 'A', 'B', 'C', 'C', 'C', 'A', 'B', 'C', 'A', 'B', 'C', 'A', 'A', 'A']
# Complexity:  B

# %% [markdown]
# ## Timber

# %%
TradeSweep = open("./timber/TradeSweep.py", "r").read()
baseline1 = open("./timber/baseline1.py", "r").read()
baseline2 = open("./timber/baseline2.py", "r").read()
baseline3 = open("./timber/baseline3.py", "r").read()

# %%
# TradeSweep

pylint_scores, radon_scores = calculate_score(TradeSweep)
print("=============== TradeSweep ===============")
print("\n\n----------- Pylint ----------")
print(pylint_scores)
print("Avg: ", round(sum(pylint_scores)/len(pylint_scores), 2))

print("\n----------- Radon ----------")
print("# of lines: ", radon_scores['lineno'])
print("Avg # of lines: ", round(sum(radon_scores['lineno'])/len(radon_scores['lineno']), 2))
print("\nComplexity: ", radon_scores['complexity'])
print("Complexity: ", round(sum(radon_scores['complexity'])/len(radon_scores['complexity']), 2))
print("\nComplexity rank: ", [cc_rank(score) for score in radon_scores['complexity']])
print("Complexity: ", cc_rank(int(sum(radon_scores['complexity'])/len(radon_scores['complexity']))))
# Out:
# ************* Module test
# test.py:6:0: C0301: Line too long (229/100) (line-too-long)
# test.py:8:0: C0301: Line too long (227/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:19: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.86/10 (previous run: 5.83/10, -2.98)
#
# ************* Module test
# test.py:11:0: C0301: Line too long (139/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:16: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
# test.py:12:8: W0702: No exception type(s) specified (bare-except)
# test.py:12:16: C0321: More than one statement on a single line (multiple-statements)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 2.86/10, +2.14)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:15: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.25/10 (previous run: 5.00/10, +1.25)
#
# ************* Module test
# test.py:8:0: C0301: Line too long (132/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:32: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.29/10 (previous run: 6.25/10, -1.96)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:38: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 4.29/10, +0.71)
#
# ************* Module test
# test.py:7:0: C0301: Line too long (113/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:32: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 3.33/10 (previous run: 5.00/10, -1.67)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (209/100) (line-too-long)
# test.py:8:0: C0301: Line too long (103/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:32: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.83/10 (previous run: 3.33/10, +2.50)
#
# ************* Module test
# test.py:8:0: C0301: Line too long (152/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:36: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.29/10 (previous run: 5.83/10, -1.55)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:37: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:1:0: W0611: Unused import pycountry (unused-import)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.56/10 (previous run: 4.29/10, +1.27)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (106/100) (line-too-long)
# test.py:8:0: C0301: Line too long (123/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:27: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.86/10 (previous run: 5.56/10, -2.70)
#
# ************* Module test
# test.py:6:218: C0303: Trailing whitespace (trailing-whitespace)
# test.py:6:0: C0301: Line too long (218/100) (line-too-long)
# test.py:8:0: C0301: Line too long (135/100) (line-too-long)
# test.py:15:0: C0301: Line too long (103/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:29: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.17/10 (previous run: 2.86/10, +1.31)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:13: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.71/10 (previous run: 4.17/10, +1.55)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (176/100) (line-too-long)
# test.py:8:0: C0301: Line too long (136/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:14: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.83/10 (previous run: 5.71/10, +0.12)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:30: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
# test.py:10:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:10:23: C0321: More than one statement on a single line (multiple-statements)
# test.py:9:8: W0612: Unused variable 'i' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.71/10 (previous run: 5.83/10, -0.12)
#
# ************* Module test
# test.py:13:0: C0301: Line too long (226/100) (line-too-long)
# test.py:46:51: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:11:0: R0914: Too many local variables (30/15) (too-many-locals)
# test.py:11:24: W0621: Redefining name 'df' from outer scope (line 8) (redefined-outer-name)
# test.py:20:4: W0702: No exception type(s) specified (bare-except)
# test.py:28:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:40:20: W0702: No exception type(s) specified (bare-except)
# test.py:48:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:56:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:62:15: R0124: Redundant comparison - value != value (comparison-with-itself)
# test.py:65:27: R0124: Redundant comparison - value_tmp != value_tmp (comparison-with-itself)
# test.py:68:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:72:11: R0124: Redundant comparison - name_before != name_before (comparison-with-itself)
# test.py:72:37: C0321: More than one statement on a single line (multiple-statements)
# test.py:11:0: R0912: Too many branches (21/12) (too-many-branches)
# test.py:11:0: R0915: Too many statements (52/50) (too-many-statements)
# test.py:61:19: W0612: Unused variable 'cnt' (unused-variable)
# test.py:64:31: W0612: Unused variable 'cnt_tmp' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.21/10 (previous run: 5.71/10, +1.49)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (111/100) (line-too-long)
# test.py:9:40: W1401: Anomalous backslash in string: '\s'. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:22: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.44/10 (previous run: 7.21/10, -2.76)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (126/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:22: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:1:0: W0611: Unused import string (unused-import)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.83/10 (previous run: 4.44/10, +1.39)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (132/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:21: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:1:0: W0611: Unused import string (unused-import)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 5.83/10, -0.83)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:31: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
# test.py:11:11: R0124: Redundant comparison - name != name (comparison-with-itself)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.33/10 (previous run: 5.00/10, +2.33)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (183/100) (line-too-long)
# test.py:9:0: C0301: Line too long (210/100) (line-too-long)
# test.py:27:0: C0301: Line too long (175/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:16:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:16:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:23:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 7.33/10, -0.97)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (132/100) (line-too-long)
# test.py:8:0: C0301: Line too long (367/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:29:0: C0301: Line too long (102/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 6.36/10, -0.71)
#
# ************* Module test
# test.py:10:0: C0301: Line too long (171/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:18: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
# test.py:14:11: R0124: Redundant comparison - name != name (comparison-with-itself)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.33/10 (previous run: 5.65/10, +1.68)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (189/100) (line-too-long)
# test.py:9:0: C0301: Line too long (210/100) (line-too-long)
# test.py:27:0: C0301: Line too long (137/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:16:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:16:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:23:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 7.33/10, -0.97)
#
# ************* Module test
# test.py:13:0: C0301: Line too long (226/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:11:0: R0914: Too many local variables (30/15) (too-many-locals)
# test.py:11:24: W0621: Redefining name 'df' from outer scope (line 8) (redefined-outer-name)
# test.py:20:4: W0702: No exception type(s) specified (bare-except)
# test.py:28:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:40:20: W0702: No exception type(s) specified (bare-except)
# test.py:48:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:56:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:62:15: R0124: Redundant comparison - value != value (comparison-with-itself)
# test.py:65:27: R0124: Redundant comparison - value_tmp != value_tmp (comparison-with-itself)
# test.py:68:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:72:11: R0124: Redundant comparison - name_before != name_before (comparison-with-itself)
# test.py:72:37: C0321: More than one statement on a single line (multiple-statements)
# test.py:11:0: R0912: Too many branches (21/12) (too-many-branches)
# test.py:11:0: R0915: Too many statements (52/50) (too-many-statements)
# test.py:61:19: W0612: Unused variable 'cnt' (unused-variable)
# test.py:64:31: W0612: Unused variable 'cnt_tmp' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.35/10 (previous run: 6.36/10, +0.99)
#
# =============== TradeSweep ===============
#
#
# ----------- Pylint ----------
# [2.8571428571428568, 5.0, 6.25, 4.2857142857142865, 5.0, 3.333333333333334, 5.833333333333333, 4.2857142857142865, 5.555555555555555, 2.8571428571428568, 4.166666666666666, 5.714285714285714, 5.833333333333333, 5.714285714285714, 7.205882352941177, 4.444444444444445, 5.833333333333333, 5.0, 7.333333333333334, 6.363636363636363, 5.6521739130434785, 7.333333333333334, 6.363636363636363, 7.352941176470589]
# Avg:  5.4
#
# ----------- Radon ----------
# # of lines:  [7, 8, 6, 7, 6, 6, 7, 7, 7, 7, 7, 7, 7, 8, 11, 7, 7, 7, 8, 7, 6, 8, 7, 11]
# Avg # of lines:  7.33
#
# Complexity:  [1, 3, 1, 1, 1, 1, 3, 1, 3, 1, 3, 1, 3, 3, 20, 2, 3, 2, 3, 6, 12, 3, 6, 20]
# Complexity:  4.29
#
# Complexity rank:  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'C', 'A', 'A', 'A', 'A', 'B', 'C', 'A', 'B', 'C']
# Complexity:  A

# %%
# Baseline 1

pylint_scores, radon_scores = calculate_score(baseline1)
print("=============== Baseline 1 ===============")
print("\n\n----------- Pylint ----------")
print(pylint_scores)
print("Avg: ", round(sum(pylint_scores)/len(pylint_scores), 2))

print("\n----------- Radon ----------")
print("# of lines: ", radon_scores['lineno'])
print("Avg # of lines: ", round(sum(radon_scores['lineno'])/len(radon_scores['lineno']), 2))
print("\nComplexity: ", radon_scores['complexity'])
print("Complexity: ", round(sum(radon_scores['complexity'])/len(radon_scores['complexity']), 2))
print("\nComplexity rank: ", [cc_rank(score) for score in radon_scores['complexity']])
print("Complexity: ", cc_rank(int(sum(radon_scores['complexity'])/len(radon_scores['complexity']))))
# Out:
# ************* Module test
# test.py:6:0: C0301: Line too long (227/100) (line-too-long)
# test.py:8:0: C0301: Line too long (232/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:17: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 1.67/10 (previous run: 7.35/10, -5.69)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:15: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.71/10 (previous run: 1.67/10, +4.05)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:15: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.00/10 (previous run: 5.71/10, -1.71)
#
# ************* Module test
# test.py:8:0: C0301: Line too long (144/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:32: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.29/10 (previous run: 4.00/10, +0.29)
#
# ************* Module test
# test.py:7:0: C0301: Line too long (137/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:33: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 3.33/10 (previous run: 4.29/10, -0.95)
#
# ************* Module test
# test.py:9:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:12:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.86/10 (previous run: 3.33/10, -0.48)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (211/100) (line-too-long)
# test.py:7:0: C0301: Line too long (123/100) (line-too-long)
# test.py:8:0: C0301: Line too long (104/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:27: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:8:29: R1721: Unnecessary use of a comprehension, use dict(trading_countries[['ISO2CTY', 'Country']].values) instead. (unnecessary-comprehension)
#
# ------------------------------------------------------------------
# Your code has been rated at 1.25/10 (previous run: 2.86/10, -1.61)
#
# ************* Module test
# test.py:9:0: C0301: Line too long (112/100) (line-too-long)
# test.py:10:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:20: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.86/10 (previous run: 1.25/10, +1.61)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (106/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:35: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 3.33/10 (previous run: 2.86/10, +0.48)
#
# ************* Module test
# test.py:6:107: E2515: Invalid unescaped character zero-width-space, use "\u200B" instead. (invalid-character-zero-width-space)
# test.py:6:0: C0301: Line too long (107/100) (line-too-long)
# test.py:8:0: C0301: Line too long (123/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:31: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 0.00/10 (previous run: 3.33/10, -3.33)
#
# ************* Module test
# test.py:5:297: C0303: Trailing whitespace (trailing-whitespace)
# test.py:5:0: C0301: Line too long (297/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:44: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:7:4: C0103: Variable name "df_ISO_230" doesn't conform to snake_case naming style (invalid-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.00/10 (previous run: 0.00/10, +4.00)
#
# ************* Module test
# test.py:9:0: C0301: Line too long (105/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:17: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.29/10 (previous run: 4.00/10, +0.29)
#
# ************* Module test
# test.py:5:262: C0303: Trailing whitespace (trailing-whitespace)
# test.py:5:0: C0301: Line too long (262/100) (line-too-long)
# test.py:7:0: C0301: Line too long (135/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:19: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.50/10 (previous run: 4.29/10, -1.79)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:25: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:6:29: W0613: Unused argument 'col' (unused-argument)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.29/10 (previous run: 2.50/10, +1.79)
#
# ************* Module test
# test.py:9:0: C0301: Line too long (106/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:26: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 4.29/10, +0.71)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (126/100) (line-too-long)
# test.py:8:0: C0301: Line too long (155/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:22: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:1:0: W0611: Unused import string (unused-import)
#
# ------------------------------------------------------------------
# Your code has been rated at 1.43/10 (previous run: 5.00/10, -3.57)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (132/100) (line-too-long)
# test.py:7:0: C0301: Line too long (159/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 1.67/10 (previous run: 1.43/10, +0.24)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (134/100) (line-too-long)
# test.py:7:0: C0301: Line too long (153/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:21: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 1.67/10 (previous run: 1.67/10, +0.00)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:27: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 1.67/10, +3.33)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (277/100) (line-too-long)
# test.py:9:0: C0301: Line too long (160/100) (line-too-long)
# test.py:10:0: C0301: Line too long (144/100) (line-too-long)
# test.py:11:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:15:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:18:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:22:147: C0303: Trailing whitespace (trailing-whitespace)
# test.py:22:0: C0301: Line too long (147/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:20: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:19:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:7:24: W0613: Unused argument 'col' (unused-argument)
#
# ------------------------------------------------------------------
# Your code has been rated at 3.50/10 (previous run: 5.00/10, -1.50)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (164/100) (line-too-long)
# test.py:7:0: C0301: Line too long (115/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:34: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 1.67/10 (previous run: 3.50/10, -1.83)
#
# ************* Module test
# test.py:5:85: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:18: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.29/10 (previous run: 1.67/10, +2.62)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (284/100) (line-too-long)
# test.py:7:0: C0301: Line too long (140/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:26: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:10:8: R1724: Unnecessary "else" after "continue", remove the "else" and de-indent the code inside it (no-else-continue)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.71/10 (previous run: 4.29/10, +1.43)
#
# ************* Module test
# test.py:9:42: W1401: Anomalous backslash in string: '\s'. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:26: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 5.71/10, -0.71)
#
# =============== Baseline 1 ===============
#
#
# ----------- Pylint ----------
# [1.666666666666666, 5.714285714285714, 4.0, 4.2857142857142865, 3.333333333333334, 2.8571428571428568, 1.25, 2.8571428571428568, 3.333333333333334, 0, 4.0, 4.2857142857142865, 2.5, 4.2857142857142865, 5.0, 1.4285714285714288, 1.666666666666666, 1.666666666666666, 5.0, 3.5, 1.666666666666666, 4.2857142857142865, 5.714285714285714, 5.0]
# Avg:  3.3
#
# ----------- Radon ----------
# # of lines:  [7, 6, 6, 7, 6, 6, 6, 7, 6, 7, 6, 7, 6, 6, 6, 7, 6, 6, 6, 7, 6, 6, 6, 6]
# Avg # of lines:  6.29
#
# Complexity:  [1, 1, 1, 1, 1, 1, 2, 1, 1, 1, 3, 1, 1, 1, 2, 1, 1, 1, 1, 7, 1, 1, 5, 2]
# Complexity:  1.62
#
# Complexity rank:  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'B', 'A', 'A', 'A', 'A']
# Complexity:  A

# %%
# Baseline 2

pylint_scores, radon_scores = calculate_score(baseline2)
print("=============== Baseline 2 ===============")
print("\n\n----------- Pylint ----------")
print(pylint_scores)
print("Avg: ", round(sum(pylint_scores)/len(pylint_scores), 2))

print("\n----------- Radon ----------")
print("# of lines: ", radon_scores['lineno'])
print("Avg # of lines: ", round(sum(radon_scores['lineno'])/len(radon_scores['lineno']), 2))
print("\nComplexity: ", radon_scores['complexity'])
print("Complexity: ", round(sum(radon_scores['complexity'])/len(radon_scores['complexity']), 2))
print("\nComplexity rank: ", [cc_rank(score) for score in radon_scores['complexity']])
print("Complexity: ", cc_rank(int(sum(radon_scores['complexity'])/len(radon_scores['complexity']))))
# Out:
# ************* Module test
# test.py:6:0: C0301: Line too long (226/100) (line-too-long)
# test.py:8:0: C0301: Line too long (232/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:17: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 1.67/10 (previous run: 5.33/10, -3.67)
#
# ************* Module test
# test.py:11:0: C0301: Line too long (133/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:16: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
# test.py:12:8: W0702: No exception type(s) specified (bare-except)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.83/10 (previous run: 1.67/10, +4.17)
#
# ************* Module test
# test.py:7:18: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:14: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:2:0: W0611: Unused numpy imported as np (unused-import)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.86/10 (previous run: 5.83/10, -2.98)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (103/100) (line-too-long)
# test.py:8:0: C0301: Line too long (144/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:24: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.86/10 (previous run: 2.86/10, +0.00)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (108/100) (line-too-long)
# test.py:9:0: C0301: Line too long (184/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:24: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 2.86/10, +2.14)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:26: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.71/10 (previous run: 5.00/10, +0.71)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (205/100) (line-too-long)
# test.py:9:0: C0301: Line too long (140/100) (line-too-long)
# test.py:11:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:14:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:19:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:21:0: C0301: Line too long (119/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:33: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.50/10 (previous run: 5.71/10, -3.21)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (107/100) (line-too-long)
# test.py:8:0: C0301: Line too long (152/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:24: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.86/10 (previous run: 2.50/10, +0.36)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (113/100) (line-too-long)
# test.py:9:0: C0301: Line too long (184/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:22: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 2.86/10, +2.14)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (116/100) (line-too-long)
# test.py:11:0: C0301: Line too long (103/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:29: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:7:33: W0613: Unused argument 'col' (unused-argument)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.50/10 (previous run: 5.00/10, -2.50)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (213/100) (line-too-long)
# test.py:7:37: C0303: Trailing whitespace (trailing-whitespace)
# test.py:8:0: C0301: Line too long (140/100) (line-too-long)
# test.py:9:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:11:67: C0303: Trailing whitespace (trailing-whitespace)
# test.py:12:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:13:0: C0301: Line too long (117/100) (line-too-long)
# test.py:15:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:17:87: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:0: C0103: Function name "DestinationCountryCodeToCountryName" doesn't conform to snake_case naming style (invalid-name)
# test.py:6:40: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 0.00/10 (previous run: 2.50/10, -2.50)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:19: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.27/10 (previous run: 0.00/10, +7.27)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (197/100) (line-too-long)
# test.py:18:0: C0301: Line too long (214/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:0: R0913: Too many arguments (6/5) (too-many-arguments)
# test.py:7:33: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:10:4: W0702: No exception type(s) specified (bare-except)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.33/10 (previous run: 7.27/10, -1.94)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:18: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 8.00/10 (previous run: 5.33/10, +2.67)
#
# ************* Module test
# test.py:13:0: C0301: Line too long (226/100) (line-too-long)
# test.py:46:51: C0303: Trailing whitespace (trailing-whitespace)
# test.py:75:0: C0301: Line too long (118/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:11:0: R0914: Too many local variables (30/15) (too-many-locals)
# test.py:11:24: W0621: Redefining name 'df' from outer scope (line 8) (redefined-outer-name)
# test.py:20:4: W0702: No exception type(s) specified (bare-except)
# test.py:28:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:40:20: W0702: No exception type(s) specified (bare-except)
# test.py:48:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:56:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:62:15: R0124: Redundant comparison - value != value (comparison-with-itself)
# test.py:65:27: R0124: Redundant comparison - value_tmp != value_tmp (comparison-with-itself)
# test.py:68:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:72:11: R0124: Redundant comparison - name_before != name_before (comparison-with-itself)
# test.py:72:37: C0321: More than one statement on a single line (multiple-statements)
# test.py:11:0: R0912: Too many branches (21/12) (too-many-branches)
# test.py:11:0: R0915: Too many statements (52/50) (too-many-statements)
# test.py:61:19: W0612: Unused variable 'cnt' (unused-variable)
# test.py:64:31: W0612: Unused variable 'cnt_tmp' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.06/10 (previous run: 8.00/10, -0.94)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (139/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 7.06/10, -0.70)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (141/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 6.36/10, +0.00)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (138/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:21: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:14:5: E0602: Undefined variable 'clean_stat_values' (undefined-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 1.82/10 (previous run: 6.36/10, -4.55)
#
# ************* Module test
# test.py:8:21: C0303: Trailing whitespace (trailing-whitespace)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:17: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 8.00/10 (previous run: 1.82/10, +6.18)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (189/100) (line-too-long)
# test.py:8:0: C0301: Line too long (108/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:13:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:20:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 8.00/10, -1.64)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (153/100) (line-too-long)
# test.py:8:0: C0301: Line too long (283/100) (line-too-long)
# test.py:16:0: C0301: Line too long (118/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0103: Function name "clean_SenderNameEng" doesn't conform to snake_case naming style (invalid-name)
# test.py:6:24: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:18:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:24:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:24:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 6.36/10, -0.71)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:18: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 8.00/10 (previous run: 5.65/10, +2.35)
#
# ************* Module test
# test.py:6:196: E2515: Invalid unescaped character zero-width-space, use "\u200B" instead. (invalid-character-zero-width-space)
# test.py:6:0: C0301: Line too long (196/100) (line-too-long)
# test.py:24:0: C0301: Line too long (176/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:13:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:20:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.09/10 (previous run: 8.00/10, -3.91)
#
# ************* Module test
# test.py:13:0: C0301: Line too long (226/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:11:0: R0914: Too many local variables (30/15) (too-many-locals)
# test.py:11:24: W0621: Redefining name 'df' from outer scope (line 8) (redefined-outer-name)
# test.py:20:4: W0702: No exception type(s) specified (bare-except)
# test.py:28:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:40:20: W0702: No exception type(s) specified (bare-except)
# test.py:48:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:56:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:62:15: R0124: Redundant comparison - value != value (comparison-with-itself)
# test.py:65:27: R0124: Redundant comparison - value_tmp != value_tmp (comparison-with-itself)
# test.py:68:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:72:11: R0124: Redundant comparison - name_before != name_before (comparison-with-itself)
# test.py:72:37: C0321: More than one statement on a single line (multiple-statements)
# test.py:11:0: R0912: Too many branches (21/12) (too-many-branches)
# test.py:11:0: R0915: Too many statements (52/50) (too-many-statements)
# test.py:61:19: W0612: Unused variable 'cnt' (unused-variable)
# test.py:64:31: W0612: Unused variable 'cnt_tmp' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.35/10 (previous run: 4.09/10, +3.26)
#
# =============== Baseline 2 ===============
#
#
# ----------- Pylint ----------
# [1.666666666666666, 5.833333333333333, 2.8571428571428568, 2.8571428571428568, 5.0, 5.714285714285714, 2.5, 2.8571428571428568, 5.0, 2.5, 0, 7.272727272727273, 5.333333333333333, 8.0, 7.0588235294117645, 6.363636363636363, 6.363636363636363, 1.8181818181818183, 8.0, 6.363636363636363, 5.6521739130434785, 8.0, 4.090909090909091, 7.352941176470589]
# Avg:  4.94
#
# ----------- Radon ----------
# # of lines:  [7, 8, 7, 7, 7, 6, 7, 7, 7, 7, 6, 7, 7, 8, 11, 6, 6, 6, 8, 7, 6, 8, 7, 11]
# Avg # of lines:  7.25
#
# Complexity:  [1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 1, 5, 4, 3, 20, 3, 3, 3, 3, 6, 12, 3, 6, 20]
# Complexity:  4.42
#
# Complexity rank:  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'C', 'A', 'A', 'A', 'A', 'B', 'C', 'A', 'B', 'C']
# Complexity:  A

# %%
# Baseline 3

pylint_scores, radon_scores = calculate_score(baseline3)
print("=============== Baseline 3 ===============")
print("\n\n----------- Pylint ----------")
print(pylint_scores)
print("Avg: ", round(sum(pylint_scores)/len(pylint_scores), 2))

print("\n----------- Radon ----------")
print("# of lines: ", radon_scores['lineno'])
print("Avg # of lines: ", round(sum(radon_scores['lineno'])/len(radon_scores['lineno']), 2))
print("\nComplexity: ", radon_scores['complexity'])
print("Complexity: ", round(sum(radon_scores['complexity'])/len(radon_scores['complexity']), 2))
print("\nComplexity rank: ", [cc_rank(score) for score in radon_scores['complexity']])
print("Complexity: ", cc_rank(int(sum(radon_scores['complexity'])/len(radon_scores['complexity']))))
# Out:
# ************* Module test
# test.py:6:0: C0301: Line too long (229/100) (line-too-long)
# test.py:11:0: C0301: Line too long (231/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:19: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.86/10 (previous run: 7.35/10, -4.50)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:16: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.71/10 (previous run: 2.86/10, +2.86)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:17: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 5.71/10, -0.71)
#
# ************* Module test
# test.py:9:21: W1401: Anomalous backslash in string: '\('. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# test.py:9:23: W1401: Anomalous backslash in string: '\)'. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:19: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.45/10 (previous run: 5.00/10, +0.45)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:38: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 5.45/10, -0.45)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (108/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:34: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.00/10 (previous run: 5.00/10, +0.00)
#
# ************* Module test
# test.py:5:261: E2515: Invalid unescaped character zero-width-space, use "\u200B" instead. (invalid-character-zero-width-space)
# test.py:5:0: C0301: Line too long (261/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:29: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 0.00/10 (previous run: 5.00/10, -5.00)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:24: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.71/10 (previous run: 0.00/10, +5.71)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (106/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:27: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 3.33/10 (previous run: 5.71/10, -2.38)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (134/100) (line-too-long)
# test.py:8:0: C0301: Line too long (123/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:38: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 2.86/10 (previous run: 3.33/10, -0.48)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (218/100) (line-too-long)
# test.py:9:0: C0301: Line too long (115/100) (line-too-long)
# test.py:18:0: C0301: Line too long (202/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:0: R0913: Too many arguments (6/5) (too-many-arguments)
# test.py:7:39: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:10:4: W0702: No exception type(s) specified (bare-except)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.67/10 (previous run: 2.86/10, +1.81)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:21: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.25/10 (previous run: 4.67/10, +1.58)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (209/100) (line-too-long)
# test.py:9:0: C0301: Line too long (115/100) (line-too-long)
# test.py:18:0: C0301: Line too long (119/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:0: R0913: Too many arguments (6/5) (too-many-arguments)
# test.py:7:39: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:10:4: W0702: No exception type(s) specified (bare-except)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.67/10 (previous run: 6.25/10, -1.58)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:29: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 8.12/10 (previous run: 4.67/10, +3.46)
#
# ************* Module test
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:11:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:11:0: R0914: Too many local variables (30/15) (too-many-locals)
# test.py:11:24: W0621: Redefining name 'df' from outer scope (line 8) (redefined-outer-name)
# test.py:17:4: W0702: No exception type(s) specified (bare-except)
# test.py:25:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:37:20: W0702: No exception type(s) specified (bare-except)
# test.py:45:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:53:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:59:15: R0124: Redundant comparison - value != value (comparison-with-itself)
# test.py:62:27: R0124: Redundant comparison - value_tmp != value_tmp (comparison-with-itself)
# test.py:65:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:69:11: R0124: Redundant comparison - name_before != name_before (comparison-with-itself)
# test.py:69:37: C0321: More than one statement on a single line (multiple-statements)
# test.py:11:0: R0912: Too many branches (21/12) (too-many-branches)
# test.py:11:0: R0915: Too many statements (52/50) (too-many-statements)
# test.py:58:19: W0612: Unused variable 'cnt' (unused-variable)
# test.py:61:31: W0612: Unused variable 'cnt_tmp' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.35/10 (previous run: 8.12/10, -0.77)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (126/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:18: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 4.29/10 (previous run: 7.35/10, -3.07)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (126/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:18: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.56/10 (previous run: 4.29/10, +1.27)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (132/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:21: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:9:50: E0602: Undefined variable 're' (undefined-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 0.00/10 (previous run: 5.56/10, -5.56)
#
# ************* Module test
# test.py:18:0: C0301: Line too long (103/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:27: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.33/10 (previous run: 0.00/10, +7.33)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (198/100) (line-too-long)
# test.py:24:0: C0301: Line too long (131/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:13:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:20:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 7.33/10, -0.97)
#
# ************* Module test
# test.py:5:0: C0301: Line too long (132/100) (line-too-long)
# test.py:13:0: C0301: Line too long (118/100) (line-too-long)
# test.py:26:0: C0301: Line too long (102/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:6:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:6:22: W0621: Redefining name 'df' from outer scope (line 3) (redefined-outer-name)
# test.py:10:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:15:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:21:4: C0206: Consider iterating with .items() (consider-using-dict-items)
# test.py:21:20: C0201: Consider iterating the dictionary directly instead of calling .keys() (consider-iterating-dictionary)
#
# ------------------------------------------------------------------
# Your code has been rated at 5.65/10 (previous run: 6.36/10, -0.71)
#
# ************* Module test
# test.py:15:23: W1401: Anomalous backslash in string: '\ '. String constant might be missing an r prefix. (anomalous-backslash-in-string)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:8:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:8:18: W0621: Redefining name 'df' from outer scope (line 5) (redefined-outer-name)
#
# ------------------------------------------------------------------
# Your code has been rated at 7.33/10 (previous run: 5.65/10, +1.68)
#
# ************* Module test
# test.py:6:0: C0301: Line too long (189/100) (line-too-long)
# test.py:24:0: C0301: Line too long (137/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:7:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:7:25: W0621: Redefining name 'df' from outer scope (line 4) (redefined-outer-name)
# test.py:13:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:13:25: C0321: More than one statement on a single line (multiple-statements)
# test.py:20:11: C0121: Comparison 'keyword != None' should be 'keyword is not None' (singleton-comparison)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.36/10 (previous run: 7.33/10, -0.97)
#
# ************* Module test
# test.py:20:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:24:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:48:51: C0303: Trailing whitespace (trailing-whitespace)
# test.py:49:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:57:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:74:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:82:0: C0303: Trailing whitespace (trailing-whitespace)
# test.py:84:0: C0301: Line too long (104/100) (line-too-long)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# test.py:11:0: C0116: Missing function or method docstring (missing-function-docstring)
# test.py:11:0: R0914: Too many local variables (30/15) (too-many-locals)
# test.py:11:24: W0621: Redefining name 'df' from outer scope (line 8) (redefined-outer-name)
# test.py:18:4: W0702: No exception type(s) specified (bare-except)
# test.py:30:11: R0124: Redundant comparison - name != name (comparison-with-itself)
# test.py:42:20: W0702: No exception type(s) specified (bare-except)
# test.py:52:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:62:8: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:68:15: R0124: Redundant comparison - value != value (comparison-with-itself)
# test.py:71:27: R0124: Redundant comparison - value_tmp != value_tmp (comparison-with-itself)
# test.py:76:4: C0200: Consider using enumerate instead of iterating with range and len (consider-using-enumerate)
# test.py:80:11: R0124: Redundant comparison - name_before != name_before (comparison-with-itself)
# test.py:80:37: C0321: More than one statement on a single line (multiple-statements)
# test.py:11:0: R0912: Too many branches (21/12) (too-many-branches)
# test.py:11:0: R0915: Too many statements (52/50) (too-many-statements)
# test.py:67:19: W0612: Unused variable 'cnt' (unused-variable)
# test.py:70:31: W0612: Unused variable 'cnt_tmp' (unused-variable)
#
# ------------------------------------------------------------------
# Your code has been rated at 6.18/10 (previous run: 6.36/10, -0.19)
#
# =============== Baseline 3 ===============
#
#
# ----------- Pylint ----------
# [2.8571428571428568, 5.714285714285714, 5.0, 5.454545454545455, 5.0, 5.0, 0, 5.714285714285714, 3.333333333333334, 2.8571428571428568, 4.666666666666667, 6.25, 4.666666666666667, 8.125, 7.352941176470589, 4.2857142857142865, 5.555555555555555, 0, 7.333333333333334, 6.363636363636363, 5.6521739130434785, 7.333333333333334, 6.363636363636363, 6.176470588235294]
# Avg:  5.04
#
# ----------- Radon ----------
# # of lines:  [7, 6, 6, 7, 6, 6, 6, 7, 6, 7, 7, 7, 7, 8, 11, 6, 6, 6, 8, 7, 6, 8, 7, 11]
# Avg # of lines:  7.04
#
# Complexity:  [2, 1, 1, 2, 1, 1, 1, 1, 1, 1, 4, 1, 4, 3, 20, 1, 1, 2, 3, 6, 12, 3, 6, 20]
# Complexity:  4.08
#
# Complexity rank:  ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'C', 'A', 'A', 'A', 'A', 'B', 'C', 'A', 'B', 'C']
# Complexity:  A
